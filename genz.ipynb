# %%
import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

conn = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="",
    database="genz_erd"
)

print("Koneksi berhasil!")
# Out:
# Koneksi berhasil!

# %%
query = "SELECT * FROM genz_social_media_usage LIMIT 10000"
df = pd.read_sql(query, conn)
print(df.shape)
df.head()
# Out:
# (10000, 12)
# C:\Users\Advan\AppData\Local\Temp\ipykernel_19760\2446803406.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#    age  gender    country  daily_usage_hours primary_platform  \
# 0   19    Male  Australia           2.658617         Snapchat
# 1   16  Female        USA           5.685387          Twitter
# 2   25  Female      India           2.782420           TikTok
# 3   27    Male      India           3.486598          YouTube
# 4   23  Female      India           3.748829           TikTok
#
#    num_platforms_used        purpose  avg_session_minutes  night_usage  \
# 0                   4      Education            29.222443            0
# 1                   3    Socializing            32.464726            1
# 2                   2    Socializing            18.170204            1
# 3                   4      Education            22.493804            1
# 4                   1  Entertainment            27.358410            1
#
#    mental_health_score addiction_level  screen_time_before_sleep
# 0             6.705830          Medium                 15.779443
# 1             6.633111            High                 47.714864
# 2             6.035397          Medium                 62.524625
# 3             8.110861          Medium                 31.935102
# 4             6.658598          Medium                 29.466046

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       10000 non-null  int64
#  1   gender                    10000 non-null  str
#  2   country                   10000 non-null  str
#  3   daily_usage_hours         10000 non-null  float64
#  4   primary_platform          10000 non-null  str
#  5   num_platforms_used        10000 non-null  int64
#  6   purpose                   10000 non-null  str
#  7   avg_session_minutes       10000 non-null  float64
#  8   night_usage               10000 non-null  int64
#  9   mental_health_score       10000 non-null  float64
#  10  addiction_level           10000 non-null  str
#  11  screen_time_before_sleep  10000 non-null  float64
# dtypes: float64(4), int64(3), str(5)
# memory usage: 937.6 KB

# %%
df.describe()
# Out:
#                age  daily_usage_hours  num_platforms_used  \
# count  10000.00000       10000.000000        10000.000000
# mean      19.99620           3.520766            2.964000
# std        4.32387           1.458981            1.420319
# min       13.00000           0.500000            1.000000
# 25%       16.00000           2.509631            2.000000
# 50%       20.00000           3.503011            3.000000
# 75%       24.00000           4.505582            4.000000
# max       27.00000           9.107881            5.000000
#
#        avg_session_minutes   night_usage  mental_health_score  \
# count         10000.000000  10000.000000         10000.000000
# mean             25.223800      0.595700             7.174822
# std               9.719112      0.490781             1.503615
# min               5.000000      0.000000             1.000000
# 25%              18.586185      0.000000             6.165269
# 50%              25.076631      1.000000             7.215892
# 75%              31.815611      1.000000             8.241803
# max              67.877736      1.000000            10.000000
#
#        screen_time_before_sleep
# count              10000.000000
# mean                  40.204798
# std                   19.525215
# min                    0.000000
# 25%                   26.616160
# 50%                   39.898470
# 75%                   53.450654
# max                  114.302103

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x='primary_platform', order=df['primary_platform'].value_counts().index)
plt.title('Platform Terpopuler')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
